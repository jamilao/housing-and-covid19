# %%
# imports
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from pathlib import Path

# directory and file paths
data_dir = Path("../data/")
raw_data_dir = data_dir / "raw"
processed_data_dir = data_dir / "processed"
interim_data_dir = data_dir / "interim"

raw_rental_vacancy_file = raw_data_dir / "rental_vacancy_rates_75.csv"
raw_homeowner_vacancy_file = raw_data_dir / "homeowner_vacancy_rates_75.csv"
raw_homeownership_file = raw_data_dir / "homeownership_rates_75.csv"
raw_covid_cases_file = raw_data_dir / "COVID-19_Case_Surveillance_Public_Use_Data.csv"

interim_rental_vacancy_file = interim_data_dir / "rental_vacancy_rates_75.csv"
interim_homeowner_vacancy_file = interim_data_dir / "homeowner_vacancy_rates_75.csv"
interim_homeownership_file = interim_data_dir / "homeownership_rates_75.csv"

# %% [markdown]
# # Housing Vacancies and Homeownership (Census Data)

# %% [markdown]
# ## Rental Vacancy Rates for the 75 Largest MSAs (2015 - 2020)

# %%
# import dataset
rental_vacancy_df = pd.read_csv(interim_rental_vacancy_file)
rental_vacancy_df.head()
# Out:
#                        Metropolitan Statistical Area  \
# 0  Akron, OH .......................................
# 1  Albany-Schenectady-Troy, NY .....................
# 2  Albuquerque, NM..................................
# 3  Allentown-Bethlehem-Easton, PA-NJ................
# 4  Atlanta-Sandy Springs-Roswell, GA1...............
#
#   First         Quarter       2020 Margin of Error1  \
# 0                             10.2              9.2
# 1                              7.9              6.7
# 2                              4.3              2.8
# 3                              4.5              5.9
# 4                              6.9              2.5
#
#   Second         Quarter       2020 Margin of Error1.1  \
# 0                               8.1                8.5
# 1                               6.7                5.6
# 2                               6.9                  4
# 3                               5.6                6.6
# 4                               5.1                2.3
#
#   Third         Quarter       2020 Margin of Error1.2  \
# 0                              3.3                5.3
# 1                             10.1                7.1
# 2                              6.8                3.4
# 3                              2.9                4.2
# 4                              5.8                2.4
#
#    Fourth         Quarter       2020  Margin of Error1.3  \
# 0                                3.6                 5.0
# 1                               15.3                10.2
# 2                                4.1                 2.5
# 3                                2.5                 4.9
# 4                                7.7                 2.7
#
#    First         Quarter       2019  ...  Fourth         Quarter       2016  \
# 0                               2.0  ...                                5.2
# 1                               7.9  ...                                3.6
# 2                               7.1  ...                               11.6
# 3                               7.7  ...                                4.6
# 4                               7.8  ...                                6.4
#
#    Margin of Error1.18  First Quarter 2015  Margin of Error3  \
# 0                  8.0                 3.5               5.1
# 1                  4.6                 9.6               6.8
# 2                  4.3                 7.3               3.3
# 3                  6.7                 3.5               4.6
# 4                  2.6                 9.5               2.5
#
#   Second Quarter 2015  Margin of Error3.1  Third Quarter 2015  \
# 0                14.6                 9.7                19.9
# 1                 7.9                 5.7                 5.6
# 2                 7.7                 3.3                 7.4
# 3                 3.4                 5.1                 6.0
# 4                 8.4                 2.3                 7.9
#
#    Margin of Error3.2  Fourth Quarter 2015  Margin of Error3.3
# 0                11.9                 10.3                 8.9
# 1                 5.1                  3.0                 3.9
# 2                 3.6                  6.4                 3.5
# 3                 6.3                  2.4                 3.7
# 4                 2.3                  6.8                 2.3
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Homeowner Vacancy Rates for the 75 Largest MSAs (2015 - 2020)

# %%
# import dataset
homeowner_vacancy_df = pd.read_csv(interim_homeowner_vacancy_file)
homeowner_vacancy_df.head()
# Out:
#                        Metropolitan Statistical Area  \
# 0  Akron, OH .......................................
# 1  Albany-Schenectady-Troy, NY .....................
# 2  Albuquerque, NM..................................
# 3  Allentown-Bethlehem-Easton, PA-NJ................
# 4  Atlanta-Sandy Springs-Roswell, GA1...............
#
#   First         Quarter       2020 Margin of Error1  \
# 0                              0.5              1.4
# 1                              0.9              1.9
# 2                                2              1.3
# 3                              0.6              1.4
# 4                              1.2              0.8
#
#   Second         Quarter       2020 Margin of Error1.1  \
# 0                               0.5                1.4
# 1                               0.9                1.9
# 2                               1.6                1.1
# 3                               0.5                1.4
# 4                                 1                0.7
#
#   Third         Quarter       2020 Margin of Error1.2  \
# 0                              0.5                1.5
# 1                              5.3                4.2
# 2                                1                  1
# 3                              0.5                1.4
# 4                              0.3                0.4
#
#   Fourth         Quarter       2020 Margin of Error1.3  \
# 0                               (z)                (z)
# 1                               4.9                  4
# 2                               0.7                0.8
# 3                               1.3                2.2
# 4                               0.8                0.7
#
#    First         Quarter       2019  ... Fourth         Quarter       2016  \
# 0                               0.0  ...                               0.5
# 1                               1.6  ...                               2.2
# 2                               1.9  ...                               1.5
# 3                               1.2  ...                               1.8
# 4                               0.9  ...                               1.5
#
#    Margin of Error1.18  First Quarter 2015  Margin of Error3  \
# 0                  1.6                 0.0               (z)
# 1                  2.9                 1.3                 2
# 2                  1.3                 2.5               1.6
# 3                  2.9                 0.5               1.2
# 4                    1                 2.9               1.2
#
#   Second Quarter 2015  Margin of Error3.1  Third Quarter 2015  \
# 0                 0.5                 1.3                 0.8
# 1                 2.8                 2.7                 1.8
# 2                 3.9                   2                 2.5
# 3                 2.5                 2.7                 2.1
# 4                 2.4                 1.1                 1.8
#
#    Margin of Error3.2 Fourth Quarter 2015  Margin of Error3.3
# 0                 1.5                 0.5                 1.3
# 1                 2.1                 1.1                 1.7
# 2                 1.6                 2.1                 1.5
# 3                 2.5                 2.0                 2.6
# 4                 0.9                 1.7                 0.9
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Homeownership Rates for the 75 Largest MSAs (2015 - 2020)

# %%
# import dataset
homeownership_df = pd.read_csv(interim_homeownership_file)
homeownership_df.head()
# Out:
#                        Metropolitan Statistical Area  \
# 0  Akron, OH .......................................
# 1  Albany-Schenectady-Troy, NY .....................
# 2  Albuquerque, NM..................................
# 3  Allentown-Bethlehem-Easton, PA-NJ................
# 4  Atlanta-Sandy Springs-Roswell, GA1...............
#
#    First         Quarter       2020  Margin of Error1  \
# 0                              71.9               9.7
# 1                              62.9               9.7
# 2                              70.9               4.4
# 3                              73.1               8.7
# 4                              63.7               3.8
#
#    Second         Quarter       2020  Margin of Error1.1  \
# 0                               71.7                 9.9
# 1                               57.7                 9.6
# 2                               77.2                 4.1
# 3                               69.3                 9.5
# 4                               68.3                 3.6
#
#    Third         Quarter       2020  Margin of Error1.2  \
# 0                              68.5                10.1
# 1                              62.3                 9.5
# 2                              66.9                 4.7
# 3                              61.4                 9.6
# 4                              66.6                 3.6
#
#    Fourth         Quarter       2020  Margin of Error1.3  \
# 0                               66.4                 9.6
# 1                               73.1                 9.2
# 2                               63.1                 4.7
# 3                               71.9                 9.6
# 4                               67.0                 3.7
#
#    First         Quarter       2019  ...  Fourth         Quarter       2016  \
# 0                              68.3  ...                               73.2
# 1                              60.9  ...                               60.9
# 2                              72.1  ...                               64.7
# 3                              70.5  ...                               68.4
# 4                              62.6  ...                               61.6
#
#    Margin of Error1.18  First Quarter 2015  Margin of Error3  \
# 0                 10.2                68.6               8.7
# 1                  9.2                65.9               8.2
# 2                  4.8                63.8               4.6
# 3                 10.2                69.2               7.7
# 4                  3.9                60.5               3.3
#
#    Second Quarter 2015  Margin of Error3.1  Third Quarter 2015  \
# 0                 73.9                 8.0                79.9
# 1                 63.5                 7.7                66.6
# 2                 60.5                 4.8                65.9
# 3                 72.7                 8.0                71.5
# 4                 59.9                 3.2                60.9
#
#    Margin of Error3.2  Fourth Quarter 2015  Margin of Error3.3
# 0                 7.3                 73.4                 8.4
# 1                 7.5                 67.5                 7.4
# 2                 4.7                 67.4                 4.7
# 3                 8.0                 63.5                 8.6
# 4                 3.2                 65.5                 3.1
#
# [5 rows x 49 columns]

# %% [markdown]
# # COVID-19 Case Surveillance Public Use Data (CDC Data)

# %%
# import dataset
covid_cases_df = pd.read_csv(raw_covid_cases_file)
covid_cases_df.head()
# Out:
# /Users/jamila/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   cdc_case_earliest_dt  cdc_report_dt pos_spec_dt    onset_dt  \
# 0            2020/01/01    2021/01/31  2020/01/01         NaN
# 1            2020/01/01    2021/02/02  2020/01/01         NaN
# 2            2020/01/02    2021/01/27  2020/01/02         NaN
# 3            2020/01/02    2021/02/02  2020/01/02         NaN
# 4            2021/01/01    2020/01/03  2020/01/03  2021/01/01
#
#               current_status     sex    age_group race_ethnicity_combined  \
# 0  Laboratory-confirmed case  Female  0 - 9 Years                 Unknown
# 1  Laboratory-confirmed case    Male  0 - 9 Years                 Unknown
# 2  Laboratory-confirmed case    Male  0 - 9 Years                 Unknown
# 3  Laboratory-confirmed case    Male  0 - 9 Years                 Unknown
# 4  Laboratory-confirmed case    Male  0 - 9 Years     White, Non-Hispanic
#
#    hosp_yn   icu_yn death_yn medcond_yn
# 0  Missing  Missing       No    Missing
# 1  Missing  Missing       No    Missing
# 2  Missing  Missing       No    Missing
# 3  Missing  Missing       No    Missing
# 4       No  Missing       No        Yes
